# %%
import torch, os
import numpy as np
import time
import sys
sys.path.append('model')

from model.parsingnet import parsingNet
from model.dataloader import get_train_loader
from model.loss import SoftmaxFocalLoss, ParsingRelationLoss, ParsingRelationDis
from model.metrics import MultiLabelAcc, AccTopk, Metric_mIoU, update_metrics, reset_metrics

# %%
def inference(net, data_label, use_aux ,device):
    # 用于将参数送入网络并计算结果，并返回一个字典供计算损失
    if use_aux:
        img, cls_label, seg_label = data_label
        cls_label = cls_label.long()
        seg_label = seg_label.long()
        if device==torch.device('cuda:0'):
            img, cls_label, seg_label = img.cuda(), cls_label.cuda(), seg_label.cuda()
        cls_out, seg_out = net(img)
        return {'cls_out': cls_out, 'cls_label': cls_label, 'seg_out':seg_out, 'seg_label': seg_label}
    else:
        img, cls_label = data_label
        if device == torch.device('cuda:0'):
            img, cls_label = img.cuda(), cls_label.cuda()
        cls_out = net(img)
        return {'cls_out': cls_out, 'cls_label': cls_label}

# %%
def resolve_val_data(results, use_aux):
    # 取出结果的最大值位置，供计算损失用
    results['cls_out'] = torch.argmax(results['cls_out'], dim=1)
    if use_aux:
        results['seg_out'] = torch.argmax(results['seg_out'], dim=1)
    return results

# %%
def get_loss_dict(use_aux = True):
    # 生成一个用于计算损失的字典
    if use_aux:
        loss_dict = {
            'name': ['cls_loss', 'relation_loss', 'aux_loss', 'relation_dis'],
            'op': [SoftmaxFocalLoss(2), ParsingRelationLoss(), torch.nn.CrossEntropyLoss(), ParsingRelationDis()],
            'weight': [1.0, 1.0, 1.0, 0.0],
            'data_src': [('cls_out', 'cls_label'), ('cls_out',), ('seg_out', 'seg_label'), ('cls_out',)]
        }

    else:
        loss_dict = {
            'name': ['cls_loss', 'relation_loss', 'relation_dis'],
            'op': [SoftmaxFocalLoss(2), ParsingRelationLoss(), ParsingRelationDis()],
            'weight': [1.0, 1.0, 0.0],
            'data_src': [('cls_out', 'cls_label'), ('cls_out',), ('cls_out',)]
        }

    return loss_dict

# %%
def calc_loss(loss_dict, results):
    # 计算损失
    loss = 0
    for i in range(len(loss_dict['name'])):
        data_src = loss_dict['data_src'][i]
        datas = [results[src] for src in data_src]
        loss_cur = loss_dict['op'][i](*datas)
        loss += loss_cur * loss_dict['weight'][i]
    return loss


def get_metric_dict(use_aux = True):
    # 生成计算指标的字典
    if use_aux:
        metric_dict = {
            'name': ['top1', 'top2', 'top3', 'iou'],
            'op': [MultiLabelAcc(), AccTopk(100, 2), AccTopk(100, 3), Metric_mIoU(5)],
            'data_src': [('cls_out', 'cls_label'), ('cls_out', 'cls_label'), ('cls_out', 'cls_label'),
                         ('seg_out', 'seg_label')]
        }
    else:
        metric_dict = {
            'name': ['top1', 'top2', 'top3'],
            'op': [MultiLabelAcc(), AccTopk(100, 2), AccTopk(100, 3)],
            'data_src': [('cls_out', 'cls_label'), ('cls_out', 'cls_label'), ('cls_out', 'cls_label')]
        }

    return metric_dict

# %%
def train(epoches, net, loss_dict, metric_dict, train_loader, optimizer, use_aux,device,save_path):
    train_loader_size = len(train_loader)
    for epoch in range(epoches):
        print(f"Epoch {epoch + 1}")
        step = 0
        reset_metrics(metric_dict)
        for batch_idx, data_label in enumerate(train_loader):
            start = time.time()
            step += 1
            results = inference(net, data_label, use_aux, device)
            loss = calc_loss(loss_dict, results)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            end = time.time()
            batch_time = end - start
            results = resolve_val_data(results, use_aux)
            update_metrics(metric_dict, results)

            if step % 10 == 0:
                print(
                    "Epoch {ep} Step {st} |({batch}/{size})| ETA: {et:.2f}|MultiLabelAcc:{MultiLabelAcc:.5f}|AccTop2:{AccTop2:.5f}|AccTop3:{AccTop3:.5f}|Metric_mIoU:{Metric_mIoU:.5f}".format(
                        ep=epoch + 1,
                        st=step,
                        batch=batch_idx + 1,
                        size=train_loader_size,
                        et=batch_time,
                        MultiLabelAcc=metric_dict['op'][0].get(),
                        AccTop2=metric_dict['op'][1].get(),
                        AccTop3=metric_dict['op'][2].get(),
                        Metric_mIoU=metric_dict['op'][3].get(),
                    ))
        if (epoch + 1) % 5 == 0:
            print("should save model")
            torch.save(net.state_dict(), os.path.join(save_path, ('parsenet_'+str(epoch+1)+'.pth')))
    return metric_dict

# %%
torch.cuda.empty_cache()
epoches = 100
batch_size = 16
data_root = r'./tusimple_0531'
griding_num = 100
dataset = 'Tusimple'
use_aux = True
distributed = False
backbone = '50'
num_lanes = 4
learning_rate = 0.001
save_path = './save_pth'
if not os.path.isdir(save_path):
    os.mkdir(save_path)
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
train_loader, cls_num_per_lane = get_train_loader(batch_size, data_root, griding_num, dataset, use_aux,distributed)
net = parsingNet(pretrained=True, backbone=backbone,cls_dim = (griding_num+1,cls_num_per_lane, num_lanes),use_aux=use_aux)
net = net.to(device)
optimizer = torch.optim.Adam(net.parameters(), learning_rate)
loss_dict = get_loss_dict(use_aux)
metric_dict = get_metric_dict(use_aux)

# %%
train(epoches, net, loss_dict, metric_dict, train_loader, optimizer, use_aux,device,save_path)
# Out:
# Epoch 1
# Epoch 1 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.44565|AccTop2:0.46099|AccTop3:0.47497|Metric_mIoU:0.17521
# Epoch 1 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.48126|AccTop2:0.49513|AccTop3:0.50878|Metric_mIoU:0.19384
# Epoch 2
# Epoch 2 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.51596|AccTop2:0.52896|AccTop3:0.54166|Metric_mIoU:0.23854
# Epoch 2 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.51621|AccTop2:0.53006|AccTop3:0.54375|Metric_mIoU:0.25549
# Epoch 3
# Epoch 3 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.52277|AccTop2:0.53979|AccTop3:0.55759|Metric_mIoU:0.34253
# Epoch 3 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.51996|AccTop2:0.53962|AccTop3:0.55963|Metric_mIoU:0.36997
# Epoch 4
# Epoch 4 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.53030|AccTop2:0.55650|AccTop3:0.58491|Metric_mIoU:0.45907
# Epoch 4 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.52383|AccTop2:0.55172|AccTop3:0.58015|Metric_mIoU:0.47376
# Epoch 5
# Epoch 5 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.52871|AccTop2:0.56362|AccTop3:0.59707|Metric_mIoU:0.50074
# Epoch 5 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.52521|AccTop2:0.55830|AccTop3:0.59110|Metric_mIoU:0.51787
# should save model
# Epoch 6
# Epoch 6 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.54227|AccTop2:0.57720|AccTop3:0.61035|Metric_mIoU:0.55407
# Epoch 6 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.53379|AccTop2:0.56910|AccTop3:0.60269|Metric_mIoU:0.56377
# Epoch 7
# Epoch 7 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.53284|AccTop2:0.57095|AccTop3:0.60603|Metric_mIoU:0.58106
# Epoch 7 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.53258|AccTop2:0.57134|AccTop3:0.60752|Metric_mIoU:0.58342
# Epoch 8
# Epoch 8 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.52991|AccTop2:0.56487|AccTop3:0.59986|Metric_mIoU:0.58564
# Epoch 8 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.52864|AccTop2:0.56533|AccTop3:0.60201|Metric_mIoU:0.58774
# Epoch 9
# Epoch 9 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.53136|AccTop2:0.56895|AccTop3:0.60472|Metric_mIoU:0.60599
# Epoch 9 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.52912|AccTop2:0.56936|AccTop3:0.60555|Metric_mIoU:0.60498
# Epoch 10
# Epoch 10 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.53248|AccTop2:0.57285|AccTop3:0.61295|Metric_mIoU:0.61461
# Epoch 10 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.53298|AccTop2:0.57550|AccTop3:0.61542|Metric_mIoU:0.62183
# should save model
# Epoch 11
# Epoch 11 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.54026|AccTop2:0.59018|AccTop3:0.63404|Metric_mIoU:0.65102
# Epoch 11 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.53825|AccTop2:0.59083|AccTop3:0.63665|Metric_mIoU:0.64353
# Epoch 12
# Epoch 12 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.54534|AccTop2:0.60728|AccTop3:0.66060|Metric_mIoU:0.64665
# Epoch 12 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.54054|AccTop2:0.60396|AccTop3:0.65792|Metric_mIoU:0.64476
# Epoch 13
# Epoch 13 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.55441|AccTop2:0.61766|AccTop3:0.66830|Metric_mIoU:0.66213
# Epoch 13 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.54872|AccTop2:0.61823|AccTop3:0.67186|Metric_mIoU:0.65610
# Epoch 14
# Epoch 14 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.54545|AccTop2:0.61987|AccTop3:0.67673|Metric_mIoU:0.65298
# Epoch 14 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.55338|AccTop2:0.63312|AccTop3:0.69104|Metric_mIoU:0.65711
# Epoch 15
# Epoch 15 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.56663|AccTop2:0.65466|AccTop3:0.71828|Metric_mIoU:0.65095
# Epoch 15 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.56045|AccTop2:0.64955|AccTop3:0.71332|Metric_mIoU:0.65039
# should save model
# Epoch 16
# Epoch 16 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.57277|AccTop2:0.66744|AccTop3:0.73161|Metric_mIoU:0.67047
# Epoch 16 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.56735|AccTop2:0.66592|AccTop3:0.73214|Metric_mIoU:0.66628
# Epoch 17
# Epoch 17 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.58209|AccTop2:0.67706|AccTop3:0.73482|Metric_mIoU:0.67184
# Epoch 17 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.57334|AccTop2:0.67559|AccTop3:0.74182|Metric_mIoU:0.67823
# Epoch 18
# Epoch 18 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.58354|AccTop2:0.69459|AccTop3:0.75795|Metric_mIoU:0.68780
# Epoch 18 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.57727|AccTop2:0.69082|AccTop3:0.75551|Metric_mIoU:0.67686
# Epoch 19
# Epoch 19 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.58348|AccTop2:0.69643|AccTop3:0.76543|Metric_mIoU:0.67599
# Epoch 19 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.58527|AccTop2:0.70625|AccTop3:0.77441|Metric_mIoU:0.68100
# Epoch 20
# Epoch 20 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.59411|AccTop2:0.70873|AccTop3:0.77617|Metric_mIoU:0.69224
# Epoch 20 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.58961|AccTop2:0.71196|AccTop3:0.78110|Metric_mIoU:0.68765
# should save model
# Epoch 21
# Epoch 21 Step 10 |(10/23)| ETA: 2.01|MultiLabelAcc:0.59983|AccTop2:0.72960|AccTop3:0.79537|Metric_mIoU:0.70213
# Epoch 21 Step 20 |(20/23)| ETA: 2.01|MultiLabelAcc:0.59791|AccTop2:0.72866|AccTop3:0.79587|Metric_mIoU:0.69637
# Epoch 22
# Epoch 22 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.60106|AccTop2:0.73770|AccTop3:0.80625|Metric_mIoU:0.69270
# Epoch 22 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.59845|AccTop2:0.73698|AccTop3:0.80573|Metric_mIoU:0.70042
# Epoch 23
# Epoch 23 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.60407|AccTop2:0.73965|AccTop3:0.80427|Metric_mIoU:0.70616
# Epoch 23 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.60589|AccTop2:0.74431|AccTop3:0.80894|Metric_mIoU:0.70280
# Epoch 24
# Epoch 24 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.61270|AccTop2:0.74950|AccTop3:0.81456|Metric_mIoU:0.71075
# Epoch 24 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.60636|AccTop2:0.74692|AccTop3:0.81518|Metric_mIoU:0.71538
# Epoch 25
# Epoch 25 Step 10 |(10/23)| ETA: 2.01|MultiLabelAcc:0.61300|AccTop2:0.75737|AccTop3:0.82475|Metric_mIoU:0.71974
# Epoch 25 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.60961|AccTop2:0.75513|AccTop3:0.82165|Metric_mIoU:0.71742
# should save model
# Epoch 26
# Epoch 26 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.61390|AccTop2:0.75463|AccTop3:0.82056|Metric_mIoU:0.71006
# Epoch 26 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.61385|AccTop2:0.76147|AccTop3:0.82842|Metric_mIoU:0.71274
# Epoch 27
# Epoch 27 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.61314|AccTop2:0.76055|AccTop3:0.82497|Metric_mIoU:0.72233
# Epoch 27 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.61475|AccTop2:0.76440|AccTop3:0.82920|Metric_mIoU:0.71860
# Epoch 28
# Epoch 28 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.63412|AccTop2:0.78167|AccTop3:0.84420|Metric_mIoU:0.72553
# Epoch 28 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.63142|AccTop2:0.78174|AccTop3:0.84259|Metric_mIoU:0.71911
# Epoch 29
# Epoch 29 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.63253|AccTop2:0.77893|AccTop3:0.83585|Metric_mIoU:0.74063
# Epoch 29 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.63054|AccTop2:0.78167|AccTop3:0.84142|Metric_mIoU:0.74069
# Epoch 30
# Epoch 30 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.63158|AccTop2:0.78789|AccTop3:0.85218|Metric_mIoU:0.73567
# Epoch 30 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.62892|AccTop2:0.78852|AccTop3:0.84953|Metric_mIoU:0.73240
# should save model
# Epoch 31
# Epoch 31 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.63435|AccTop2:0.79515|AccTop3:0.85120|Metric_mIoU:0.73846
# Epoch 31 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.63068|AccTop2:0.79521|AccTop3:0.85186|Metric_mIoU:0.73892
# Epoch 32
# Epoch 32 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.63438|AccTop2:0.79124|AccTop3:0.84947|Metric_mIoU:0.74643
# Epoch 32 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.63396|AccTop2:0.79559|AccTop3:0.85395|Metric_mIoU:0.74104
# Epoch 33
# Epoch 33 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.64495|AccTop2:0.80898|AccTop3:0.86490|Metric_mIoU:0.74347
# Epoch 33 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.63902|AccTop2:0.80232|AccTop3:0.85975|Metric_mIoU:0.74529
# Epoch 34
# Epoch 34 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.65265|AccTop2:0.81604|AccTop3:0.86730|Metric_mIoU:0.75796
# Epoch 34 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.64453|AccTop2:0.80692|AccTop3:0.86230|Metric_mIoU:0.75455
# Epoch 35
# Epoch 35 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.64079|AccTop2:0.80675|AccTop3:0.86021|Metric_mIoU:0.75548
# Epoch 35 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.64594|AccTop2:0.81055|AccTop3:0.86465|Metric_mIoU:0.75586
# should save model
# Epoch 36
# Epoch 36 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.64983|AccTop2:0.81373|AccTop3:0.86526|Metric_mIoU:0.76378
# Epoch 36 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.64674|AccTop2:0.80900|AccTop3:0.86334|Metric_mIoU:0.76001
# Epoch 37
# Epoch 37 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.64874|AccTop2:0.81217|AccTop3:0.86738|Metric_mIoU:0.77059
# Epoch 37 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.65372|AccTop2:0.81896|AccTop3:0.87187|Metric_mIoU:0.76278
# Epoch 38
# Epoch 38 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.64699|AccTop2:0.81303|AccTop3:0.86691|Metric_mIoU:0.75918
# Epoch 38 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.64886|AccTop2:0.81504|AccTop3:0.86840|Metric_mIoU:0.75672
# Epoch 39
# Epoch 39 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.64994|AccTop2:0.81607|AccTop3:0.86961|Metric_mIoU:0.74879
# Epoch 39 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.65460|AccTop2:0.81939|AccTop3:0.87217|Metric_mIoU:0.75227
# Epoch 40
# Epoch 40 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.65363|AccTop2:0.81878|AccTop3:0.86666|Metric_mIoU:0.77161
# Epoch 40 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.65541|AccTop2:0.82217|AccTop3:0.87387|Metric_mIoU:0.77122
# should save model
# Epoch 41
# Epoch 41 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.65310|AccTop2:0.82333|AccTop3:0.87352|Metric_mIoU:0.75859
# Epoch 41 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.65421|AccTop2:0.82450|AccTop3:0.87556|Metric_mIoU:0.76074
# Epoch 42
# Epoch 42 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.62813|AccTop2:0.77952|AccTop3:0.83834|Metric_mIoU:0.72474
# Epoch 42 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.62383|AccTop2:0.77967|AccTop3:0.84000|Metric_mIoU:0.69813
# Epoch 43
# Epoch 43 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.62651|AccTop2:0.78566|AccTop3:0.84336|Metric_mIoU:0.66878
# Epoch 43 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.63330|AccTop2:0.79202|AccTop3:0.85166|Metric_mIoU:0.67533
# Epoch 44
# Epoch 44 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.64654|AccTop2:0.80767|AccTop3:0.85862|Metric_mIoU:0.70873
# Epoch 44 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.64549|AccTop2:0.80951|AccTop3:0.86164|Metric_mIoU:0.72049
# Epoch 45
# Epoch 45 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.65050|AccTop2:0.80790|AccTop3:0.86239|Metric_mIoU:0.72345
# Epoch 45 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.64721|AccTop2:0.80936|AccTop3:0.86339|Metric_mIoU:0.73358
# should save model
# Epoch 46
# Epoch 46 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.65103|AccTop2:0.81635|AccTop3:0.86914|Metric_mIoU:0.75326
# Epoch 46 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.65466|AccTop2:0.82436|AccTop3:0.87592|Metric_mIoU:0.75430
# Epoch 47
# Epoch 47 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.64537|AccTop2:0.81666|AccTop3:0.87001|Metric_mIoU:0.75067
# Epoch 47 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.64865|AccTop2:0.81667|AccTop3:0.87147|Metric_mIoU:0.75800
# Epoch 48
# Epoch 48 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.66275|AccTop2:0.82681|AccTop3:0.87578|Metric_mIoU:0.75956
# Epoch 48 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.66148|AccTop2:0.82814|AccTop3:0.87815|Metric_mIoU:0.76834
# Epoch 49
# Epoch 49 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.66741|AccTop2:0.83203|AccTop3:0.88292|Metric_mIoU:0.77055
# Epoch 49 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.66076|AccTop2:0.82888|AccTop3:0.87927|Metric_mIoU:0.77063
# Epoch 50
# Epoch 50 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.66314|AccTop2:0.83033|AccTop3:0.88047|Metric_mIoU:0.77674
# Epoch 50 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.66215|AccTop2:0.83237|AccTop3:0.88217|Metric_mIoU:0.78462
# should save model
# Epoch 51
# Epoch 51 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.66655|AccTop2:0.83262|AccTop3:0.88139|Metric_mIoU:0.78770
# Epoch 51 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.66847|AccTop2:0.83701|AccTop3:0.88371|Metric_mIoU:0.78478
# Epoch 52
# Epoch 52 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.67963|AccTop2:0.84654|AccTop3:0.89196|Metric_mIoU:0.79138
# Epoch 52 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.67174|AccTop2:0.84155|AccTop3:0.88834|Metric_mIoU:0.78701
# Epoch 53
# Epoch 53 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.67550|AccTop2:0.84230|AccTop3:0.88912|Metric_mIoU:0.79502
# Epoch 53 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.67253|AccTop2:0.84244|AccTop3:0.88938|Metric_mIoU:0.79060
# Epoch 54
# Epoch 54 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.67330|AccTop2:0.84185|AccTop3:0.88903|Metric_mIoU:0.79396
# Epoch 54 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.67084|AccTop2:0.84135|AccTop3:0.89046|Metric_mIoU:0.79132
# Epoch 55
# Epoch 55 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.67129|AccTop2:0.83460|AccTop3:0.88239|Metric_mIoU:0.79039
# Epoch 55 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.67515|AccTop2:0.84459|AccTop3:0.89216|Metric_mIoU:0.79462
# should save model
# Epoch 56
# Epoch 56 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.67480|AccTop2:0.84375|AccTop3:0.88873|Metric_mIoU:0.80072
# Epoch 56 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.67800|AccTop2:0.84947|AccTop3:0.89519|Metric_mIoU:0.80555
# Epoch 57
# Epoch 57 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.68354|AccTop2:0.85410|AccTop3:0.89841|Metric_mIoU:0.80412
# Epoch 57 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.68043|AccTop2:0.85360|AccTop3:0.89798|Metric_mIoU:0.80097
# Epoch 58
# Epoch 58 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.68326|AccTop2:0.85248|AccTop3:0.89565|Metric_mIoU:0.80338
# Epoch 58 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.67859|AccTop2:0.85304|AccTop3:0.89813|Metric_mIoU:0.80222
# Epoch 59
# Epoch 59 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.68524|AccTop2:0.85050|AccTop3:0.89322|Metric_mIoU:0.80876
# Epoch 59 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.68672|AccTop2:0.85657|AccTop3:0.90045|Metric_mIoU:0.80578
# Epoch 60
# Epoch 60 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.68217|AccTop2:0.85499|AccTop3:0.89824|Metric_mIoU:0.82001
# Epoch 60 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.68086|AccTop2:0.85502|AccTop3:0.90061|Metric_mIoU:0.81438
# should save model
# Epoch 61
# Epoch 61 Step 10 |(10/23)| ETA: 2.01|MultiLabelAcc:0.69129|AccTop2:0.85954|AccTop3:0.90134|Metric_mIoU:0.80940
# Epoch 61 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.68616|AccTop2:0.85703|AccTop3:0.90031|Metric_mIoU:0.81079
# Epoch 62
# Epoch 62 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.69060|AccTop2:0.86060|AccTop3:0.90700|Metric_mIoU:0.81355
# Epoch 62 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.68870|AccTop2:0.85879|AccTop3:0.90458|Metric_mIoU:0.81333
# Epoch 63
# Epoch 63 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.69342|AccTop2:0.86387|AccTop3:0.90432|Metric_mIoU:0.82035
# Epoch 63 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.69095|AccTop2:0.86242|AccTop3:0.90536|Metric_mIoU:0.81536
# Epoch 64
# Epoch 64 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.69099|AccTop2:0.86699|AccTop3:0.90979|Metric_mIoU:0.81570
# Epoch 64 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.68597|AccTop2:0.86369|AccTop3:0.90792|Metric_mIoU:0.81558
# Epoch 65
# Epoch 65 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.68622|AccTop2:0.85845|AccTop3:0.90357|Metric_mIoU:0.81776
# Epoch 65 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.68802|AccTop2:0.86151|AccTop3:0.90636|Metric_mIoU:0.81835
# should save model
# Epoch 66
# Epoch 66 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.69757|AccTop2:0.86992|AccTop3:0.91230|Metric_mIoU:0.81883
# Epoch 66 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.69001|AccTop2:0.86613|AccTop3:0.91062|Metric_mIoU:0.81200
# Epoch 67
# Epoch 67 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.68661|AccTop2:0.85943|AccTop3:0.89941|Metric_mIoU:0.81978
# Epoch 67 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.68687|AccTop2:0.86108|AccTop3:0.90363|Metric_mIoU:0.81904
# Epoch 68
# Epoch 68 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.69263|AccTop2:0.86635|AccTop3:0.90935|Metric_mIoU:0.82814
# Epoch 68 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.68644|AccTop2:0.86152|AccTop3:0.90487|Metric_mIoU:0.81823
# Epoch 69
# Epoch 69 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.68923|AccTop2:0.86250|AccTop3:0.90572|Metric_mIoU:0.82160
# Epoch 69 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.69393|AccTop2:0.86350|AccTop3:0.90737|Metric_mIoU:0.82476
# Epoch 70
# Epoch 70 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.69520|AccTop2:0.86903|AccTop3:0.91253|Metric_mIoU:0.82712
# Epoch 70 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.69403|AccTop2:0.86770|AccTop3:0.91020|Metric_mIoU:0.82346
# should save model
# Epoch 71
# Epoch 71 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.69618|AccTop2:0.86858|AccTop3:0.91264|Metric_mIoU:0.83627
# Epoch 71 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.69282|AccTop2:0.86484|AccTop3:0.90932|Metric_mIoU:0.82672
# Epoch 72
# Epoch 72 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.69612|AccTop2:0.86724|AccTop3:0.90915|Metric_mIoU:0.83561
# Epoch 72 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.69523|AccTop2:0.86825|AccTop3:0.91041|Metric_mIoU:0.82891
# Epoch 73
# Epoch 73 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.69576|AccTop2:0.87215|AccTop3:0.91459|Metric_mIoU:0.83078
# Epoch 73 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.69618|AccTop2:0.87235|AccTop3:0.91381|Metric_mIoU:0.82656
# Epoch 74
# Epoch 74 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.70519|AccTop2:0.87215|AccTop3:0.91297|Metric_mIoU:0.82913
# Epoch 74 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.70276|AccTop2:0.87193|AccTop3:0.91189|Metric_mIoU:0.83251
# Epoch 75
# Epoch 75 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.70248|AccTop2:0.87559|AccTop3:0.91853|Metric_mIoU:0.83497
# Epoch 75 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.69914|AccTop2:0.87360|AccTop3:0.91515|Metric_mIoU:0.83206
# should save model
# Epoch 76
# Epoch 76 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.70717|AccTop2:0.87556|AccTop3:0.91194|Metric_mIoU:0.83426
# Epoch 76 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.70476|AccTop2:0.87455|AccTop3:0.91403|Metric_mIoU:0.83933
# Epoch 77
# Epoch 77 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.70614|AccTop2:0.88337|AccTop3:0.92324|Metric_mIoU:0.84458
# Epoch 77 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.70372|AccTop2:0.87909|AccTop3:0.91963|Metric_mIoU:0.83965
# Epoch 78
# Epoch 78 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.70218|AccTop2:0.88016|AccTop3:0.91842|Metric_mIoU:0.83518
# Epoch 78 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.70163|AccTop2:0.87977|AccTop3:0.91924|Metric_mIoU:0.83410
# Epoch 79
# Epoch 79 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.70265|AccTop2:0.87723|AccTop3:0.91819|Metric_mIoU:0.84454
# Epoch 79 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.70286|AccTop2:0.87487|AccTop3:0.91543|Metric_mIoU:0.83933
# Epoch 80
# Epoch 80 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.71258|AccTop2:0.87748|AccTop3:0.91624|Metric_mIoU:0.83773
# Epoch 80 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.70819|AccTop2:0.87787|AccTop3:0.91790|Metric_mIoU:0.83246
# should save model
# Epoch 81
# Epoch 81 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.70123|AccTop2:0.87539|AccTop3:0.91895|Metric_mIoU:0.83052
# Epoch 81 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.70502|AccTop2:0.87819|AccTop3:0.91921|Metric_mIoU:0.83226
# Epoch 82
# Epoch 82 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.70614|AccTop2:0.87734|AccTop3:0.91635|Metric_mIoU:0.82648
# Epoch 82 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.70504|AccTop2:0.87810|AccTop3:0.91731|Metric_mIoU:0.82846
# Epoch 83
# Epoch 83 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.70742|AccTop2:0.88225|AccTop3:0.92042|Metric_mIoU:0.83766
# Epoch 83 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.70667|AccTop2:0.88237|AccTop3:0.92183|Metric_mIoU:0.83693
# Epoch 84
# Epoch 84 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.70580|AccTop2:0.87260|AccTop3:0.91169|Metric_mIoU:0.83632
# Epoch 84 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.70318|AccTop2:0.87528|AccTop3:0.91596|Metric_mIoU:0.83738
# Epoch 85
# Epoch 85 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.70421|AccTop2:0.88013|AccTop3:0.91830|Metric_mIoU:0.83690
# Epoch 85 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.71144|AccTop2:0.88619|AccTop3:0.92327|Metric_mIoU:0.84243
# should save model
# Epoch 86
# Epoch 86 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.72363|AccTop2:0.89289|AccTop3:0.92938|Metric_mIoU:0.84814
# Epoch 86 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.71487|AccTop2:0.88446|AccTop3:0.92242|Metric_mIoU:0.84480
# Epoch 87
# Epoch 87 Step 10 |(10/23)| ETA: 2.01|MultiLabelAcc:0.70804|AccTop2:0.87779|AccTop3:0.92121|Metric_mIoU:0.83372
# Epoch 87 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.70682|AccTop2:0.87874|AccTop3:0.92077|Metric_mIoU:0.83713
# Epoch 88
# Epoch 88 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.70848|AccTop2:0.88248|AccTop3:0.92386|Metric_mIoU:0.83820
# Epoch 88 Step 20 |(20/23)| ETA: 2.02|MultiLabelAcc:0.71010|AccTop2:0.88435|AccTop3:0.92507|Metric_mIoU:0.83729
# Epoch 89
# Epoch 89 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.70424|AccTop2:0.88248|AccTop3:0.92419|Metric_mIoU:0.84157
# Epoch 89 Step 20 |(20/23)| ETA: 2.00|MultiLabelAcc:0.71470|AccTop2:0.88867|AccTop3:0.92765|Metric_mIoU:0.84427
# Epoch 90
# Epoch 90 Step 10 |(10/23)| ETA: 2.00|MultiLabelAcc:0.72852|AccTop2:0.89280|AccTop3:0.92863|Metric_mIoU:0.84898
# Epoch 90 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.71745|AccTop2:0.88813|AccTop3:0.92649|Metric_mIoU:0.84747
# should save model
# Epoch 91
# Epoch 91 Step 10 |(10/23)| ETA: 2.02|MultiLabelAcc:0.71869|AccTop2:0.89015|AccTop3:0.92628|Metric_mIoU:0.83610
# Epoch 91 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.71459|AccTop2:0.88867|AccTop3:0.92613|Metric_mIoU:0.84101
# Epoch 92
# Epoch 92 Step 10 |(10/23)| ETA: 2.01|MultiLabelAcc:0.72134|AccTop2:0.89096|AccTop3:0.92818|Metric_mIoU:0.85311
# Epoch 92 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.72026|AccTop2:0.89513|AccTop3:0.93103|Metric_mIoU:0.85350
# Epoch 93
# Epoch 93 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.72626|AccTop2:0.89372|AccTop3:0.92938|Metric_mIoU:0.85531
# Epoch 93 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.71603|AccTop2:0.89023|AccTop3:0.92886|Metric_mIoU:0.85053
# Epoch 94
# Epoch 94 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.72168|AccTop2:0.89347|AccTop3:0.93309|Metric_mIoU:0.84543
# Epoch 94 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.72123|AccTop2:0.89302|AccTop3:0.93163|Metric_mIoU:0.85022
# Epoch 95
# Epoch 95 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.72871|AccTop2:0.89651|AccTop3:0.93256|Metric_mIoU:0.85793
# Epoch 95 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.72616|AccTop2:0.89441|AccTop3:0.93016|Metric_mIoU:0.85705
# should save model
# Epoch 96
# Epoch 96 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.71643|AccTop2:0.89581|AccTop3:0.93379|Metric_mIoU:0.86729
# Epoch 96 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.71723|AccTop2:0.89396|AccTop3:0.93185|Metric_mIoU:0.86131
# Epoch 97
# Epoch 97 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.73125|AccTop2:0.89788|AccTop3:0.93223|Metric_mIoU:0.86851
# Epoch 97 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.72331|AccTop2:0.89268|AccTop3:0.92919|Metric_mIoU:0.86646
# Epoch 98
# Epoch 98 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.72210|AccTop2:0.89503|AccTop3:0.93178|Metric_mIoU:0.84939
# Epoch 98 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.71936|AccTop2:0.89392|AccTop3:0.93139|Metric_mIoU:0.84984
# Epoch 99
# Epoch 99 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.72054|AccTop2:0.89336|AccTop3:0.93251|Metric_mIoU:0.85343
# Epoch 99 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.72426|AccTop2:0.89685|AccTop3:0.93470|Metric_mIoU:0.85597
# Epoch 100
# Epoch 100 Step 10 |(10/23)| ETA: 1.99|MultiLabelAcc:0.71417|AccTop2:0.88571|AccTop3:0.92455|Metric_mIoU:0.85387
# Epoch 100 Step 20 |(20/23)| ETA: 1.99|MultiLabelAcc:0.71995|AccTop2:0.89353|AccTop3:0.93105|Metric_mIoU:0.85510
# should save model
# {'data_src': [('cls_out', 'cls_label'),
#   ('cls_out', 'cls_label'),
#   ('cls_out', 'cls_label'),
#   ('seg_out', 'seg_label')],
#  'name': ['top1', 'top2', 'top3', 'iou'],
#  'op': [<model.metrics.MultiLabelAcc at 0x7f5bc0285208>,
#   <model.metrics.AccTopk at 0x7f5bc0285358>,
#   <model.metrics.AccTopk at 0x7f5bc0285390>,
#   <model.metrics.Metric_mIoU at 0x7f5bc02853c8>]}
